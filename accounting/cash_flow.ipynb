# %%
from datetime import datetime
from cash_flow import main

main(
    year=datetime.now().year,
    journal_entries_csv="/home/t4sk/Downloads/accounting-2020.csv"
)
# Out:
# === 2020/01/01 - 2020/01/31 ===
# === 資産 ===
# 仮想通過 （BTC） 328,816
# 売掛金 -327,602
# 普通預金 -379,976
# 事業主貸 500,000
# === 負債 ===
# === 資本 ===
# === 収益 ===
# 雑所得 1,336
# 売上高 119,954
# === 費用 ===
# 支払手数料 52
# ...
# 資産 121,238
# 負債 0
# 資本 0
# 収益 121,290
# 費用 52
# 負債 + 資本 + (収益 - 費用) 121,238
#
#
# === 2020/02/01 - 2020/02/29 ===
# === 資産 ===
# 普通預金 82,665
# 売掛金 1,224
# 現金 0
# 事業主貸 361,509
# === 負債 ===
# === 資本 ===
# 事業主借 2,411
# === 収益 ===
# 雑所得 1,530
# 売上高 446,318
# === 費用 ===
# 支払手数料 2,450
# 消耗品 1,388
# 会議費 1,023
# ...
# 資産 445,398
# 負債 0
# 資本 2,411
# 収益 447,848
# 費用 4,861
# 負債 + 資本 + (収益 - 費用) 445,398
#
#
# === 2020/03/01 - 2020/03/31 ===
# === 資産 ===
# 普通預金 429,872
# 売掛金 -5,445
# === 負債 ===
# 未払金 0
# === 資本 ===
# 事業主借 15,945
# === 収益 ===
# 売上高 440,873
# === 費用 ===
# 会議費 1,419
# 消耗品 12,980
# 雑損失 14,002
# 支払手数料 2,450
# 通信費 1,540
# ...
# 資産 424,427
# 負債 0
# 資本 15,945
# 収益 440,873
# 費用 32,391
# 負債 + 資本 + (収益 - 費用) 424,427
#
#
# === 2020/04/01 - 2020/04/30 ===
# === 資産 ===
# 普通預金 117,893
# 売掛金 319,749
# ...
