# %%
from t_accounts import main

main(journal_entries_csv="/home/t4sk/Downloads/accounting-2020.csv")
# Out:
# saved t-accounts.csv
# === 売掛金 ===
# 売掛金 2019/12/30 debit 120,076 ソフトウェア開発 Sunpulse （12月分）
# 売掛金 2019/12/30 debit 327,480 ソフトウェア開発 Liquidstar （12月分）
# 売掛金 2020/01/05 credit 327,480 振込 Liquidstar （12月分） 0.40958204 BTC * 802809.00 JYP / BTC = 328816.14795035997
# 売掛金 2020/01/06 credit 120,076 振込 Sunpulse （12月分）
# 売掛金 2020/01/31 debit 119,954 ソフトウェア開発 Sunpulse （1月分）
# 売掛金 2019/12/30 debit 325,140 ソフトウェア開発 Liquidstar （1月分） 3000 USD * 108.38 JPY / USD
# 売掛金 2020/02/04 credit 119,954 振込 Sunpulse （1月分）
# 売掛金 2020/02/12 credit 325,140 振込 Liquidstar （1月分）
# 売掛金 2020/02/28 debit 119,744 ソフトウェア開発 Sunpulse （2月分）
# 売掛金 2020/02/28 debit 326,574 ソフトウェア開発 Liquidstar （2月分） 3000 USD * 108.858 JPY / USD
# 売掛金 2020/03/02 credit 119,744 振込 Sunpulse （2月分）
# 売掛金 2020/03/17 credit 326,574 振込 Liquidstar （2月分）
# 売掛金 2020/03/30 debit 118,283 ソフトウェア開発 Sunpulse （3月分）
# 売掛金 2020/03/30 debit 322,590 ソフトウェア開発 Liquidstar （3月分） 3000 USD * 107.530 JPY / USD
# 売掛金 2020/04/01 credit 118,283 振込 Sunpulse （3月分）
# ...
